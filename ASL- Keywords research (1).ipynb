# %%
import os
import pandas as pd
import numpy as np
import re
os.chdir('C:/Users/ETTTT/Dropbox/Hunter/ASL kwywords')
data=pd.read_csv("ASL.csv")
negative=pd.read_csv("negative.csv",header=None )
client=pd.read_csv("client.csv",header=None )
positive=pd.read_csv("positive.csv",header=None )

# %%
#Delete Negatve keywords 
data.loc[:,'keywordsplit']=data.loc[:,'Keyword'].apply(str.split, args=(" ", ))
#create a loop to search each line 
dff=data['keywordsplit'].apply(lambda x: [w for w in x if w in negative[0].to_list()])
Index=[]
for  i in range(len(dff)):
    if len(dff.loc[i]):
        Index.append(i)
    i+=1
data=data.drop(data.index[Index])
data
#data.to_csv(r'C:/Users/ETTTT/Desktop/select_kewords.csv', index = False)
# Out:
#                                      Keyword Currency  Avg. monthly searches  \
# 0                commercial video production      USD                     50
# 1                  video marketing solutions      USD                     10
# 2                      corporate videography      USD                     20
# 5       commercial video production services      USD                     10
# 6            motion graphics explainer video      USD                     10
# 7                      product video service      USD                     20
# 8                   branded video production      USD                     20
# 9                 promotional video services      USD                     10
# 10          explainer video production house      USD                      0
# 11                      b2b video production      USD                     10
# 12                        videography agency      USD                     10
# 13                     corporate film making      USD                     10
# 14               corporate promotional video      USD                     10
# 15         youtube video production services      USD                     10
# 16               conference video production      USD                     10
# 17            video post production services      USD                     10
# 18                    local video production      USD                     10
# 19                 production house services      USD                      0
# 20              destination video production      USD                      0
# 21                dragonfly video production      USD                     10
# 23                service production company      USD                     10
# 25                real estate video brochure      USD                     10
# 26      professional video shooting services      USD                     10
# 27                     saas explainer videos      USD                     10
# 28            international video production      USD                     10
# 29          online video production services      USD                     10
# 30                    event filming services      USD                     20
# 31         video production company services      USD                     10
# 32               2d animated explainer video      USD                     10
# 33                 real estate video company      USD                     10
# 34                best saas explainer videos      USD                     10
# 35                      promo video services      USD                     10
# 36              live action video production      USD                     10
# 37                      dfw video production      USD                     10
# 38                    vista video production      USD                     10
# 39            commercial production services      USD                     10
# 41               videography studios near me      USD                     50
# 42          event video production companies      USD                     10
# 43      whiteboard animation video companies      USD                     10
# 44         list of video production services      USD                     10
# 45           video marketing company near me      USD                     10
# 46                  digital video commercial      USD                     10
# 47           video production houses near me      USD                     10
# 48                  video production package      USD                     10
# 49                product demo video service      USD                     10
# 50                  service video production      USD                     10
# 51                      video agency near me      USD                     10
# 52     whiteboard animation video production      USD                     10
# 53                    industrial videography      USD                     10
# 54                2d explainer video company      USD                     10
# 55              3d animation explainer video      USD                     10
# 56  internal communications video production      USD                     10
# 57                      video shoot services      USD                     10
# 58              best video editing companies      USD                     10
# 59                   promotional videography      USD                     10
# 60              corporate event videographer      USD                     10
# 61           video content service providers      USD                     10
#
#    Competition  Competition (indexed value)  Top of page bid (low range)  \
# 0       Medium                         60.0                         5.19
# 1         High                         69.0                         7.85
# 2         High                         67.0                         6.05
# 5      Unknown                          NaN                          NaN
# 6       Medium                         46.0                         6.40
# 7         High                         91.0                         4.70
# 8       Medium                         45.0                         6.36
# 9          Low                         20.0                          NaN
# 10     Unknown                          NaN                          NaN
# 11        High                         97.0                          NaN
# 12     Unknown                          NaN                          NaN
# 13     Unknown                          NaN                          NaN
# 14         Low                          0.0                          NaN
# 15     Unknown                          NaN                          NaN
# 16      Medium                         43.0                          NaN
# 17        High                         67.0                          NaN
# 18        High                        100.0                          NaN
# 19     Unknown                          NaN                          NaN
# 20     Unknown                          NaN                          NaN
# 21         Low                          0.0                          NaN
# 23        High                         67.0                         2.14
# 25         Low                          0.0                          NaN
# 26         Low                          0.0                          NaN
# 27        High                         67.0                          NaN
# 28      Medium                         57.0                          NaN
# 29     Unknown                          NaN                          NaN
# 30     Unknown                          NaN                          NaN
# 31     Unknown                          NaN                          NaN
# 32      Medium                         57.0                         6.52
# 33        High                         93.0                         2.27
# 34     Unknown                          NaN                          NaN
# 35     Unknown                          NaN                          NaN
# 36        High                         74.0                         2.07
# 37     Unknown                          NaN                          NaN
# 38         Low                         14.0                          NaN
# 39     Unknown                          NaN                          NaN
# 41      Medium                         64.0                         1.40
# 42         Low                          0.0                          NaN
# 43     Unknown                          NaN                          NaN
# 44     Unknown                          NaN                          NaN
# 45        High                        100.0                         5.48
# 46     Unknown                          NaN                          NaN
# 47        High                         71.0                          NaN
# 48        High                         97.0                         2.02
# 49        High                        100.0                          NaN
# 50     Unknown                          NaN                          NaN
# 51        High                        100.0                          NaN
# 52      Medium                         50.0                          NaN
# 53        High                         79.0                          NaN
# 54     Unknown                          NaN                          NaN
# 55        High                         67.0                          NaN
# 56     Unknown                          NaN                          NaN
# 57         Low                         29.0                          NaN
# 58         Low                          0.0                          NaN
# 59     Unknown                          NaN                          NaN
# 60     Unknown                          NaN                          NaN
# 61     Unknown                          NaN                          NaN
#
#     Top of page bid (high range)  Ad impression share  \
# 0                          16.24                  NaN
# 1                          24.60                  NaN
# 2                          16.67                  NaN
# 5                            NaN                  NaN
# 6                          20.00                  NaN
# 7                          13.08                  NaN
# 8                          11.52                  NaN
# 9                            NaN                  NaN
# 10                           NaN                  NaN
# 11                           NaN                  NaN
# 12                           NaN                  NaN
# 13                           NaN                  NaN
# 14                           NaN                  NaN
# 15                           NaN                  NaN
# 16                           NaN                  NaN
# 17                           NaN                  NaN
# 18                           NaN                  NaN
# 19                           NaN                  NaN
# 20                           NaN                  NaN
# 21                           NaN                  NaN
# 23                          4.16                  NaN
# 25                           NaN                  NaN
# 26                           NaN                  NaN
# 27                           NaN                  NaN
# 28                           NaN                  NaN
# 29                           NaN                  NaN
# 30                           NaN                  NaN
# 31                           NaN                  NaN
# 32                         33.29                  NaN
# 33                         10.47                  NaN
# 34                           NaN                  NaN
# 35                           NaN                  NaN
# 36                          8.48                  NaN
# 37                           NaN                  NaN
# 38                           NaN                  NaN
# 39                           NaN                  NaN
# 41                          7.99                  NaN
# 42                           NaN                  NaN
# 43                           NaN                  NaN
# 44                           NaN                  NaN
# 45                         22.79                  NaN
# 46                           NaN                  NaN
# 47                           NaN                  NaN
# 48                          4.42                  NaN
# 49                           NaN                  NaN
# 50                           NaN                  NaN
# 51                           NaN                  NaN
# 52                           NaN                  NaN
# 53                           NaN                  NaN
# 54                           NaN                  NaN
# 55                           NaN                  NaN
# 56                           NaN                  NaN
# 57                           NaN                  NaN
# 58                           NaN                  NaN
# 59                           NaN                  NaN
# 60                           NaN                  NaN
# 61                           NaN                  NaN
#
#     Organic impression share  Organic average position  ...  \
# 0                        NaN                       NaN  ...
# 1                        NaN                       NaN  ...
# 2                        NaN                       NaN  ...
# 5                        NaN                       NaN  ...
# 6                        NaN                       NaN  ...
# 7                        NaN                       NaN  ...
# 8                        NaN                       NaN  ...
# 9                        NaN                       NaN  ...
# 10                       NaN                       NaN  ...
# 11                       NaN                       NaN  ...
# 12                       NaN                       NaN  ...
# 13                       NaN                       NaN  ...
# 14                       NaN                       NaN  ...
# 15                       NaN                       NaN  ...
# 16                       NaN                       NaN  ...
# 17                       NaN                       NaN  ...
# 18                       NaN                       NaN  ...
# 19                       NaN                       NaN  ...
# 20                       NaN                       NaN  ...
# 21                       NaN                       NaN  ...
# 23                       NaN                       NaN  ...
# 25                       NaN                       NaN  ...
# 26                       NaN                       NaN  ...
# 27                       NaN                       NaN  ...
# 28                       NaN                       NaN  ...
# 29                       NaN                       NaN  ...
# 30                       NaN                       NaN  ...
# 31                       NaN                       NaN  ...
# 32                       NaN                       NaN  ...
# 33                       NaN                       NaN  ...
# 34                       NaN                       NaN  ...
# 35                       NaN                       NaN  ...
# 36                       NaN                       NaN  ...
# 37                       NaN                       NaN  ...
# 38                       NaN                       NaN  ...
# 39                       NaN                       NaN  ...
# 41                       NaN                       NaN  ...
# 42                       NaN                       NaN  ...
# 43                       NaN                       NaN  ...
# 44                       NaN                       NaN  ...
# 45                       NaN                       NaN  ...
# 46                       NaN                       NaN  ...
# 47                       NaN                       NaN  ...
# 48                       NaN                       NaN  ...
# 49                       NaN                       NaN  ...
# 50                       NaN                       NaN  ...
# 51                       NaN                       NaN  ...
# 52                       NaN                       NaN  ...
# 53                       NaN                       NaN  ...
# 54                       NaN                       NaN  ...
# 55                       NaN                       NaN  ...
# 56                       NaN                       NaN  ...
# 57                       NaN                       NaN  ...
# 58                       NaN                       NaN  ...
# 59                       NaN                       NaN  ...
# 60                       NaN                       NaN  ...
# 61                       NaN                       NaN  ...
#
#     Searches: Feb 2020  Searches: Mar 2020  Searches: Apr 2020  \
# 0                   50                  50                  50
# 1                   10                  10                   0
# 2                   20                  20                  10
# 5                   10                  10                  10
# 6                   10                  10                  10
# 7                   20                  20                  20
# 8                   40                  30                  30
# 9                   10                  10                  10
# 10                   0                   0                   0
# 11                  10                  10                  10
# 12                  10                  10                  10
# 13                  10                   0                   0
# 14                  20                  30                  20
# 15                  10                  10                  10
# 16                  10                  10                  10
# 17                  10                  10                  10
# 18                  10                  10                   0
# 19                   0                   0                   0
# 20                   0                   0                   0
# 21                  10                  10                  10
# 23                  20                  10                  10
# 25                  10                  10                   0
# 26                   0                  10                  10
# 27                  10                  10                  10
# 28                   0                   0                   0
# 29                  10                  10                  10
# 30                   0                  10                   0
# 31                   0                  10                  10
# 32                  10                  10                  10
# 33                  10                  10                   0
# 34                   0                  10                  10
# 35                  10                  10                  10
# 36                  10                  10                  10
# 37                  10                   0                   0
# 38                  10                  10                  10
# 39                  10                   0                   0
# 41                  40                  50                  20
# 42                  10                  10                  10
# 43                  10                  10                   0
# 44                  10                  10                   0
# 45                  10                  30                  10
# 46                  10                   0                  10
# 47                  10                  10                  10
# 48                  10                  10                   0
# 49                   0                   0                   0
# 50                  10                   0                  10
# 51                  10                  10                  10
# 52                  10                  10                  10
# 53                   0                   0                  10
# 54                   0                   0                   0
# 55                  10                  10                  10
# 56                   0                  10                  10
# 57                   0                   0                  10
# 58                  10                  10                   0
# 59                   0                  10                  10
# 60                  10                  10                  10
# 61                   0                   0                   0
#
#     Searches: May 2020  Searches: Jun 2020  \
# 0                   50                  50
# 1                   10                  10
# 2                   10                  10
# 5                    0                   0
# 6                   10                  10
# 7                   30                  20
# 8                   20                  20
# 9                   10                  10
# 10                   0                   0
# 11                  10                  10
# 12                  10                   0
# 13                   0                   0
# 14                  20                  10
# 15                  10                   0
# 16                  10                  10
# 17                  10                  10
# 18                  10                  10
# 19                   0                   0
# 20                   0                   0
# 21                  10                  10
# 23                  10                  10
# 25                  10                  10
# 26                  10                  10
# 27                  10                  10
# 28                   0                  10
# 29                   0                   0
# 30                   0                   0
# 31                  10                   0
# 32                  10                  10
# 33                  10                  10
# 34                   0                   0
# 35                  10                   0
# 36                  10                  10
# 37                   0                   0
# 38                  10                  10
# 39                   0                   0
# 41                  70                  40
# 42                  10                  10
# 43                  10                   0
# 44                   0                   0
# 45                  10                  10
# 46                   0                   0
# 47                   0                  10
# 48                  10                  10
# 49                   0                  10
# 50                  10                   0
# 51                  10                  10
# 52                  10                  10
# 53                   0                  10
# 54                  10                   0
# 55                  10                  10
# 56                   0                   0
# 57                  10                  10
# 58                  10                  10
# 59                   0                   0
# 60                  10                   0
# 61                   0                   0
#
#                                      Concept: Service  Concept: Other Brands  \
# 0                         commercial video production                    NaN
# 1                                                 NaN                    NaN
# 2                          corporate video production                    NaN
# 5                         commercial video production                    NaN
# 6                                                 NaN                    NaN
# 7                                                 NaN                    NaN
# 8                                                 NaN                    NaN
# 9                        promotional video production                    NaN
# 10                                                NaN                    NaN
# 11                                                NaN                    NaN
# 12                                                NaN                    NaN
# 13                         corporate video production                    NaN
# 14  corporate video production, promotional video ...                    NaN
# 15                                                NaN                youtube
# 16                             event video production                    NaN
# 17                                                NaN                    NaN
# 18                                                NaN                    NaN
# 19                                                NaN                    NaN
# 20                                                NaN                    NaN
# 21                                                NaN                    NaN
# 23                         corporate video production                    NaN
# 25                                                NaN                    NaN
# 26                                                NaN                    NaN
# 27                                                NaN                    NaN
# 28                                                NaN                    NaN
# 29                                                NaN                    NaN
# 30                             event video production                    NaN
# 31                         corporate video production                    NaN
# 32                                                NaN                    NaN
# 33                                                NaN                    NaN
# 34                                                NaN                    NaN
# 35                       promotional video production                    NaN
# 36                                                NaN                    NaN
# 37                                                NaN              dfw video
# 38                                                NaN                    NaN
# 39                        commercial video production                    NaN
# 41                                                NaN                    NaN
# 42  corporate video production, event video produc...                    NaN
# 43                                                NaN                    NaN
# 44                                                NaN                    NaN
# 45                                                NaN                    NaN
# 46                        commercial video production                    NaN
# 47                                                NaN                    NaN
# 48                                                NaN                    NaN
# 49                                                NaN                    NaN
# 50                                                NaN                    NaN
# 51                                                NaN                    NaN
# 52                                                NaN                    NaN
# 53                                                NaN                    NaN
# 54                                                NaN                    NaN
# 55                                                NaN                    NaN
# 56                                                NaN                    NaN
# 57                                                NaN                    NaN
# 58                         corporate video production                    NaN
# 59                       promotional video production                    NaN
# 60  corporate video production, event video produc...                    NaN
# 61                                                NaN                    NaN
#
#     Concept: Non-Brands  Concept: Others  \
# 0            Non-Brands              NaN
# 1            Non-Brands              NaN
# 2            Non-Brands              NaN
# 5            Non-Brands              NaN
# 6            Non-Brands  motion graphics
# 7            Non-Brands              NaN
# 8            Non-Brands              NaN
# 9            Non-Brands              NaN
# 10           Non-Brands              NaN
# 11           Non-Brands              NaN
# 12           Non-Brands              NaN
# 13           Non-Brands              NaN
# 14           Non-Brands              NaN
# 15                  NaN              NaN
# 16           Non-Brands              NaN
# 17           Non-Brands              NaN
# 18           Non-Brands              NaN
# 19           Non-Brands              NaN
# 20           Non-Brands              NaN
# 21           Non-Brands              NaN
# 23           Non-Brands              NaN
# 25           Non-Brands              NaN
# 26           Non-Brands              NaN
# 27           Non-Brands              NaN
# 28           Non-Brands              NaN
# 29           Non-Brands              NaN
# 30           Non-Brands              NaN
# 31           Non-Brands              NaN
# 32           Non-Brands              NaN
# 33           Non-Brands              NaN
# 34           Non-Brands              NaN
# 35           Non-Brands              NaN
# 36           Non-Brands              NaN
# 37                  NaN              NaN
# 38           Non-Brands              NaN
# 39           Non-Brands              NaN
# 41           Non-Brands              NaN
# 42           Non-Brands              NaN
# 43           Non-Brands              NaN
# 44           Non-Brands              NaN
# 45           Non-Brands              NaN
# 46           Non-Brands              NaN
# 47           Non-Brands              NaN
# 48           Non-Brands              NaN
# 49           Non-Brands              NaN
# 50           Non-Brands              NaN
# 51           Non-Brands              NaN
# 52           Non-Brands              NaN
# 53           Non-Brands              NaN
# 54           Non-Brands              NaN
# 55           Non-Brands     3d animation
# 56           Non-Brands              NaN
# 57           Non-Brands              NaN
# 58           Non-Brands              NaN
# 59           Non-Brands              NaN
# 60           Non-Brands              NaN
# 61           Non-Brands              NaN
#
#                                      keywordsplit
# 0                 [commercial, video, production]
# 1                   [video, marketing, solutions]
# 2                        [corporate, videography]
# 5       [commercial, video, production, services]
# 6            [motion, graphics, explainer, video]
# 7                       [product, video, service]
# 8                    [branded, video, production]
# 9                  [promotional, video, services]
# 10          [explainer, video, production, house]
# 11                       [b2b, video, production]
# 12                          [videography, agency]
# 13                      [corporate, film, making]
# 14                [corporate, promotional, video]
# 15         [youtube, video, production, services]
# 16                [conference, video, production]
# 17            [video, post, production, services]
# 18                     [local, video, production]
# 19                  [production, house, services]
# 20               [destination, video, production]
# 21                 [dragonfly, video, production]
# 23                 [service, production, company]
# 25                [real, estate, video, brochure]
# 26      [professional, video, shooting, services]
# 27                      [saas, explainer, videos]
# 28             [international, video, production]
# 29          [online, video, production, services]
# 30                     [event, filming, services]
# 31         [video, production, company, services]
# 32               [2d, animated, explainer, video]
# 33                 [real, estate, video, company]
# 34                [best, saas, explainer, videos]
# 35                       [promo, video, services]
# 36              [live, action, video, production]
# 37                       [dfw, video, production]
# 38                     [vista, video, production]
# 39             [commercial, production, services]
# 41               [videography, studios, near, me]
# 42          [event, video, production, companies]
# 43      [whiteboard, animation, video, companies]
# 44        [list, of, video, production, services]
# 45          [video, marketing, company, near, me]
# 46                   [digital, video, commercial]
# 47          [video, production, houses, near, me]
# 48                   [video, production, package]
# 49                [product, demo, video, service]
# 50                   [service, video, production]
# 51                      [video, agency, near, me]
# 52     [whiteboard, animation, video, production]
# 53                      [industrial, videography]
# 54                [2d, explainer, video, company]
# 55              [3d, animation, explainer, video]
# 56  [internal, communications, video, production]
# 57                       [video, shoot, services]
# 58              [best, video, editing, companies]
# 59                     [promotional, videography]
# 60               [corporate, event, videographer]
# 61           [video, content, service, providers]
#
# [57 rows x 29 columns]

# %%
#Clean Client positive keywords, split by ',' & '/'
client=client[0].to_list()
client=client+client[3].split(',')+client[4].split('/')+client[11].split('/')
client=[w.lower() for w in list(client)]
client
# Out:
# ['business videos',
#  'company story video',
#  'video agency',
#  'animation, infographics, social media video, digital marketing video, landing page video, interviews/corporate videos, company story video, small business videos',
#  'sales videos/presenetation videos',
#  'new client videos',
#  'onboarding videos',
#  'recruiting videos- design',
#  'safety videos',
#  'hr videos',
#  'virtual productions',
#  'medical/video productions',
#  'hospitality videos',
#  'testimonial videos',
#  'animation',
#  ' infographics',
#  ' social media video',
#  ' digital marketing video',
#  ' landing page video',
#  ' interviews/corporate videos',
#  ' company story video',
#  ' small business videos',
#  'sales videos',
#  'presenetation videos',
#  'medical',
#  'video productions']

# %%
# Match client positive keywords
index=[]
data=data.reset_index()
for j in range(len(client)):
    for  i in range(len(data)):
        if re.findall('\\b'+client[j]+'\\b',data.loc[i,'Keyword']): 
            index.append(i)
index=list(set(index))# select unique index, as some of index shows more than once.
match=data.loc[index]
match
# Out:
#     index                                Keyword Currency  \
# 38     43   whiteboard animation video companies      USD
# 50     55           3d animation explainer video      USD
# 46     51                   video agency near me      USD
# 47     52  whiteboard animation video production      USD
#
#     Avg. monthly searches Competition  Competition (indexed value)  \
# 38                     10     Unknown                          NaN
# 50                     10        High                         67.0
# 46                     10        High                        100.0
# 47                     10      Medium                         50.0
#
#     Top of page bid (low range)  Top of page bid (high range)  \
# 38                          NaN                           NaN
# 50                          NaN                           NaN
# 46                          NaN                           NaN
# 47                          NaN                           NaN
#
#     Ad impression share  Organic impression share  ...  Searches: Feb 2020  \
# 38                  NaN                       NaN  ...                  10
# 50                  NaN                       NaN  ...                  10
# 46                  NaN                       NaN  ...                  10
# 47                  NaN                       NaN  ...                  10
#
#     Searches: Mar 2020  Searches: Apr 2020  Searches: May 2020  \
# 38                  10                   0                  10
# 50                  10                  10                  10
# 46                  10                  10                  10
# 47                  10                  10                  10
#
#     Searches: Jun 2020  Concept: Service  Concept: Other Brands  \
# 38                   0               NaN                    NaN
# 50                  10               NaN                    NaN
# 46                  10               NaN                    NaN
# 47                  10               NaN                    NaN
#
#     Concept: Non-Brands  Concept: Others  \
# 38           Non-Brands              NaN
# 50           Non-Brands     3d animation
# 46           Non-Brands              NaN
# 47           Non-Brands              NaN
#
#                                   keywordsplit
# 38   [whiteboard, animation, video, companies]
# 50           [3d, animation, explainer, video]
# 46                   [video, agency, near, me]
# 47  [whiteboard, animation, video, production]
#
# [4 rows x 30 columns]

# %%
# Match  positive keywords
index2=[]
positive=positive[0].to_list()
for j in range(len(positive)):
    for  i in range(len(data)):
        if re.findall('\\b'+positive[j]+'\\b',data.loc[i,'Keyword']): 
            index2.append(i)
index2=list(set(index2))
match2=data.loc[index2]
match2
#match2.to_csv(r'C:/Users/ETTTT/Desktop/select_kewords.csv', index = False)
# Out:
#     index                                   Keyword Currency  \
# 0       0               commercial video production      USD
# 3       5      commercial video production services      USD
# 5       7                     product video service      USD
# 6       8                  branded video production      USD
# 8      10          explainer video production house      USD
# 9      11                      b2b video production      USD
# 13     15         youtube video production services      USD
# 14     16               conference video production      USD
# 16     18                    local video production      USD
# 18     20              destination video production      USD
# 19     21                dragonfly video production      USD
# 24     28            international video production      USD
# 25     29          online video production services      USD
# 27     31         video production company services      USD
# 32     36              live action video production      USD
# 33     37                      dfw video production      USD
# 34     38                    vista video production      USD
# 37     42          event video production companies      USD
# 39     44         list of video production services      USD
# 42     47           video production houses near me      USD
# 43     48                  video production package      USD
# 44     49                product demo video service      USD
# 45     50                  service video production      USD
# 47     52     whiteboard animation video production      USD
# 49     54                2d explainer video company      USD
# 51     56  internal communications video production      USD
#
#     Avg. monthly searches Competition  Competition (indexed value)  \
# 0                      50      Medium                         60.0
# 3                      10     Unknown                          NaN
# 5                      20        High                         91.0
# 6                      20      Medium                         45.0
# 8                       0     Unknown                          NaN
# 9                      10        High                         97.0
# 13                     10     Unknown                          NaN
# 14                     10      Medium                         43.0
# 16                     10        High                        100.0
# 18                      0     Unknown                          NaN
# 19                     10         Low                          0.0
# 24                     10      Medium                         57.0
# 25                     10     Unknown                          NaN
# 27                     10     Unknown                          NaN
# 32                     10        High                         74.0
# 33                     10     Unknown                          NaN
# 34                     10         Low                         14.0
# 37                     10         Low                          0.0
# 39                     10     Unknown                          NaN
# 42                     10        High                         71.0
# 43                     10        High                         97.0
# 44                     10        High                        100.0
# 45                     10     Unknown                          NaN
# 47                     10      Medium                         50.0
# 49                     10     Unknown                          NaN
# 51                     10     Unknown                          NaN
#
#     Top of page bid (low range)  Top of page bid (high range)  \
# 0                          5.19                         16.24
# 3                           NaN                           NaN
# 5                          4.70                         13.08
# 6                          6.36                         11.52
# 8                           NaN                           NaN
# 9                           NaN                           NaN
# 13                          NaN                           NaN
# 14                          NaN                           NaN
# 16                          NaN                           NaN
# 18                          NaN                           NaN
# 19                          NaN                           NaN
# 24                          NaN                           NaN
# 25                          NaN                           NaN
# 27                          NaN                           NaN
# 32                         2.07                          8.48
# 33                          NaN                           NaN
# 34                          NaN                           NaN
# 37                          NaN                           NaN
# 39                          NaN                           NaN
# 42                          NaN                           NaN
# 43                         2.02                          4.42
# 44                          NaN                           NaN
# 45                          NaN                           NaN
# 47                          NaN                           NaN
# 49                          NaN                           NaN
# 51                          NaN                           NaN
#
#     Ad impression share  Organic impression share  ...  Searches: Feb 2020  \
# 0                   NaN                       NaN  ...                  50
# 3                   NaN                       NaN  ...                  10
# 5                   NaN                       NaN  ...                  20
# 6                   NaN                       NaN  ...                  40
# 8                   NaN                       NaN  ...                   0
# 9                   NaN                       NaN  ...                  10
# 13                  NaN                       NaN  ...                  10
# 14                  NaN                       NaN  ...                  10
# 16                  NaN                       NaN  ...                  10
# 18                  NaN                       NaN  ...                   0
# 19                  NaN                       NaN  ...                  10
# 24                  NaN                       NaN  ...                   0
# 25                  NaN                       NaN  ...                  10
# 27                  NaN                       NaN  ...                   0
# 32                  NaN                       NaN  ...                  10
# 33                  NaN                       NaN  ...                  10
# 34                  NaN                       NaN  ...                  10
# 37                  NaN                       NaN  ...                  10
# 39                  NaN                       NaN  ...                  10
# 42                  NaN                       NaN  ...                  10
# 43                  NaN                       NaN  ...                  10
# 44                  NaN                       NaN  ...                   0
# 45                  NaN                       NaN  ...                  10
# 47                  NaN                       NaN  ...                  10
# 49                  NaN                       NaN  ...                   0
# 51                  NaN                       NaN  ...                   0
#
#     Searches: Mar 2020  Searches: Apr 2020  Searches: May 2020  \
# 0                   50                  50                  50
# 3                   10                  10                   0
# 5                   20                  20                  30
# 6                   30                  30                  20
# 8                    0                   0                   0
# 9                   10                  10                  10
# 13                  10                  10                  10
# 14                  10                  10                  10
# 16                  10                   0                  10
# 18                   0                   0                   0
# 19                  10                  10                  10
# 24                   0                   0                   0
# 25                  10                  10                   0
# 27                  10                  10                  10
# 32                  10                  10                  10
# 33                   0                   0                   0
# 34                  10                  10                  10
# 37                  10                  10                  10
# 39                  10                   0                   0
# 42                  10                  10                   0
# 43                  10                   0                  10
# 44                   0                   0                   0
# 45                   0                  10                  10
# 47                  10                  10                  10
# 49                   0                   0                  10
# 51                  10                  10                   0
#
#     Searches: Jun 2020                                   Concept: Service  \
# 0                   50                        commercial video production
# 3                    0                        commercial video production
# 5                   20                                                NaN
# 6                   20                                                NaN
# 8                    0                                                NaN
# 9                   10                                                NaN
# 13                   0                                                NaN
# 14                  10                             event video production
# 16                  10                                                NaN
# 18                   0                                                NaN
# 19                  10                                                NaN
# 24                  10                                                NaN
# 25                   0                                                NaN
# 27                   0                         corporate video production
# 32                  10                                                NaN
# 33                   0                                                NaN
# 34                  10                                                NaN
# 37                  10  corporate video production, event video produc...
# 39                   0                                                NaN
# 42                  10                                                NaN
# 43                  10                                                NaN
# 44                  10                                                NaN
# 45                   0                                                NaN
# 47                  10                                                NaN
# 49                   0                                                NaN
# 51                   0                                                NaN
#
#     Concept: Other Brands  Concept: Non-Brands  Concept: Others  \
# 0                     NaN           Non-Brands              NaN
# 3                     NaN           Non-Brands              NaN
# 5                     NaN           Non-Brands              NaN
# 6                     NaN           Non-Brands              NaN
# 8                     NaN           Non-Brands              NaN
# 9                     NaN           Non-Brands              NaN
# 13                youtube                  NaN              NaN
# 14                    NaN           Non-Brands              NaN
# 16                    NaN           Non-Brands              NaN
# 18                    NaN           Non-Brands              NaN
# 19                    NaN           Non-Brands              NaN
# 24                    NaN           Non-Brands              NaN
# 25                    NaN           Non-Brands              NaN
# 27                    NaN           Non-Brands              NaN
# 32                    NaN           Non-Brands              NaN
# 33              dfw video                  NaN              NaN
# 34                    NaN           Non-Brands              NaN
# 37                    NaN           Non-Brands              NaN
# 39                    NaN           Non-Brands              NaN
# 42                    NaN           Non-Brands              NaN
# 43                    NaN           Non-Brands              NaN
# 44                    NaN           Non-Brands              NaN
# 45                    NaN           Non-Brands              NaN
# 47                    NaN           Non-Brands              NaN
# 49                    NaN           Non-Brands              NaN
# 51                    NaN           Non-Brands              NaN
#
#                                      keywordsplit
# 0                 [commercial, video, production]
# 3       [commercial, video, production, services]
# 5                       [product, video, service]
# 6                    [branded, video, production]
# 8           [explainer, video, production, house]
# 9                        [b2b, video, production]
# 13         [youtube, video, production, services]
# 14                [conference, video, production]
# 16                     [local, video, production]
# 18               [destination, video, production]
# 19                 [dragonfly, video, production]
# 24             [international, video, production]
# 25          [online, video, production, services]
# 27         [video, production, company, services]
# 32              [live, action, video, production]
# 33                       [dfw, video, production]
# 34                     [vista, video, production]
# 37          [event, video, production, companies]
# 39        [list, of, video, production, services]
# 42          [video, production, houses, near, me]
# 43                   [video, production, package]
# 44                [product, demo, video, service]
# 45                   [service, video, production]
# 47     [whiteboard, animation, video, production]
# 49                [2d, explainer, video, company]
# 51  [internal, communications, video, production]
#
# [26 rows x 30 columns]

# %%
match2.to_csv(r'C:/Users/ETTTT/Desktop/select_kewords.csv', index = False)
